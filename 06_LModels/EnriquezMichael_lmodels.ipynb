# %% [markdown]
# # Evaluación Primer Bimestre
# ---
# - **Nombre**: Michael Enríquez
# - **Fecha**: 13 de mayo, 2026
# ---
# ## Objetivo de la práctica
# El objetivo de este examen es evaluar la capacidad de los estudiantes para desarrollar un Sistema de
# Recuperación de Información capaz de indexar un corpus de documentos textuales mediante embeddings y
# recuperar los documentos más relevantes para una consulta utilizando similitud coseno.

# %% [markdown]
# ## Parte 0: Carga del Corpus
#
# Vamos a utilizar la API de Kaggle para acceder al dataset
#
# El corpus está disponible desde este [link](https://www.kaggle.com/datasets/stefanoleone992/rotten-tomatoes-movies-and-critic-reviews-dataset)
#
# #### Actividad
#
# 1. Carga el corpus

# %%
import os
import pandas as pd
import kagglehub

# Descargar dataset
path = kagglehub.dataset_download(
    'stefanoleone992/rotten-tomatoes-movies-and-critic-reviews-dataset'
)

# Cargar datos
reviews = pd.read_csv(
    os.path.join(path, 'rotten_tomatoes_critic_reviews.csv')
)

movies = pd.read_csv(
    os.path.join(path, 'rotten_tomatoes_movies.csv')
)

# Unir datasets y filtrar reviews vacías
df = (
    reviews
    .merge(
        movies[['rotten_tomatoes_link', 'movie_title']],
        on='rotten_tomatoes_link',
        how='left'
    )
    .dropna(subset=['review_content'])
    .reset_index(drop=True)
)

# Crear identificadores
df['doc_id'] = [f'doc_{i}' for i in range(len(df))]

# Documento textual
df['document'] = (
    df['movie_title'].fillna('') + ' ' +
    df['review_content'].fillna('')
)

# Validación
print(df[['doc_id', 'movie_title', 'document']].head())
print('\nShape:', df.shape)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 1.0.2)
#   doc_id                                        movie_title  \
# 0  doc_0  Percy Jackson & the Olympians: The Lightning T...
# 1  doc_1  Percy Jackson & the Olympians: The Lightning T...
# 2  doc_2  Percy Jackson & the Olympians: The Lightning T...
# 3  doc_3  Percy Jackson & the Olympians: The Lightning T...
# 4  doc_4  Percy Jackson & the Olympians: The Lightning T...
#
#                                             document
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1  Percy Jackson & the Olympians: The Lightning T...
# 2  Percy Jackson & the Olympians: The Lightning T...
# 3  Percy Jackson & the Olympians: The Lightning T...
# 4  Percy Jackson & the Olympians: The Lightning T...
#
# Shape: (1064211, 11)

# %% [markdown]
# ## Parte 1: Preprocesamiento Del Corpus

# %%
import re
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

def preprocess(text):
    text = text.lower()
    # Eliminar puntuación
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Eliminar espacios redundantes
    text = re.sub(r'\s+', ' ', text).strip()
    # Eliminar stopwords
    text = ' '.join(
        word for word in text.split()
        if word not in stop_words
    )
    return text

df['prep'] = df['document'].apply(preprocess)
print(df['prep'].iloc[0][:200])
# Out:
# percy jackson olympians lightning thief fantasy adventure fuses greek mythology contemporary american places values anyone around 15 give take couple years thrill visual spectacle

# %% [markdown]
# ## Parte 2: Generación de Embeddings

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# Opcional: reducir corpus
df = df.sample(5000, random_state=42).reset_index(drop=True)

model = SentenceTransformer('all-MiniLM-L6-v2')

embeddings = model.encode(
    df['prep'].tolist(),
    normalize_embeddings=True,
    show_progress_bar=True
)

np.save('embeddings.npy', embeddings)
print("Embeddings:", embeddings.shape)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Batches:   0%|          | 0/157 [00:00<?, ?it/s]
# Embeddings: (5000, 384)

# %% [markdown]
# ## Parte 3: Búsqueda por Similitud Coseno

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

def buscar_documentos(query, k=10):

    # Preprocesar consulta
    query = preprocess(query)

    # Embedding consulta
    query_embedding = model.encode(
        [query],
        normalize_embeddings=True
    )

    # Similitud coseno
    similarities = cosine_similarity(
        query_embedding,
        embeddings
    )[0]

    # Top-k documentos
    top_indices = similarities.argsort()[::-1][:k]

    # Resultados
    results = []

    for rank, idx in enumerate(top_indices, start=1):

        results.append({
            'Ranking': rank,
            'ID': df.iloc[idx]['doc_id'],
            'Título': df.iloc[idx]['movie_title'],
            'Fragmento': df.iloc[idx]['review_content'][:150],
            'Similitud': round(similarities[idx], 4)
        })

    return pd.DataFrame(results)

# Test de búsqueda
query = "science fiction movie with advanced technology"
results = buscar_documentos(query, k=10)
print(results)
# Out:
#    Ranking           ID                          Título  \
# 0        1   doc_990707  Transformers: Dark of the Moon
# 1        2   doc_549101                            Moon
# 2        3  doc_1009645                         Upgrade
# 3        4   doc_294791                         Elysium
# 4        5   doc_205248      Captain America: Civil War
# 5        6   doc_370871                       Hall Pass
# 6        7   doc_811223                Star Trek Beyond
# 7        8  doc_1025260               War of the Worlds
# 8        9   doc_330830                        Fracture
# 9       10   doc_101964                     After Earth
#
#                                            Fragmento  Similitud
# 0  These Transformer movies are nonsense, of cour...     0.5192
# 1  This excellent little science fiction film is ...     0.5149
# 2  Upgrade is a future-shock action horror film s...     0.4833
# 3  This is a big budget science fiction film with...     0.4831
# 4  A non-stop action movie, but they can't stop t...     0.4755
# 5  Let's just say Indiana Jones riding out a nucl...     0.4695
# 6  Michael Bay has won. Every movie has now becom...     0.4596
# 7                         great flick from spielberg     0.4544
# 8  The central mystery is a tidy piece of prestid...     0.4514
# 9  This is one of those movies where you suspect ...     0.4508

# %% [markdown]
# ## Parte 4: Ejecución de Consultas Benchmark

# %%
# Consultas benchmark
queries = {
    'Q1': 'science fiction movie with advanced technology',
    'Q2': 'romantic story with emotional relationships',
    'Q3': 'action movie with intense fight scenes',
    'Q4': 'horror film that creates fear and suspense',
    'Q5': 'visually impressive movie with weak storyline',
    'Q6': 'emotionally moving performance by the lead actor',
    'Q7': 'predictable plot but entertaining experience',
    'Q8': 'movie praised by critics but unpopular with audiences'
}

# Ejecutar búsquedas
results_by_query = {
    q_id: buscar_documentos(query, k=10)
    for q_id, query in queries.items()
}

print("Consultas benchmark ejecutadas")
# Out:
# Consultas benchmark ejecutadas

# %%
from IPython.display import display

for q_id, query in queries.items():
    print(f'\n{q_id}: {query}')
    display(results_by_query[q_id])
# Out:
# Q1: science fiction movie with advanced technology
#    Ranking           ID                          Título  \
# 0        1   doc_990707  Transformers: Dark of the Moon
# 1        2   doc_549101                            Moon
# 2        3  doc_1009645                         Upgrade
# 3        4   doc_294791                         Elysium
# 4        5   doc_205248      Captain America: Civil War
# 5        6   doc_370871                       Hall Pass
# 6        7   doc_811223                Star Trek Beyond
# 7        8  doc_1025260               War of the Worlds
# 8        9   doc_330830                        Fracture
# 9       10   doc_101964                     After Earth
#
#                                            Fragmento  Similitud
# 0  These Transformer movies are nonsense, of cour...     0.5192
# 1  This excellent little science fiction film is ...     0.5149
# 2  Upgrade is a future-shock action horror film s...     0.4833
# 3  This is a big budget science fiction film with...     0.4831
# 4  A non-stop action movie, but they can't stop t...     0.4755
# 5  Let's just say Indiana Jones riding out a nucl...     0.4695
# 6  Michael Bay has won. Every movie has now becom...     0.4596
# 7                         great flick from spielberg     0.4544
# 8  The central mystery is a tidy piece of prestid...     0.4514
# 9  This is one of those movies where you suspect ...     0.4508
# Q2: romantic story with emotional relationships
#    Ranking           ID                                             Título  \
# 0        1   doc_503575                                         Love Story
# 1        2   doc_213438                          Celeste and Jesse Forever
# 2        3   doc_501883                                Love at First Fight
# 3        4   doc_829675                                    The Story of Us
# 4        5  doc_1026072                                        Warm Bodies
# 5        6   doc_544483                             Modern Life Is Rubbish
# 6        7   doc_314327  The Father of My Children (Le pere de mes enfa...
# 7        8   doc_407271                                   I Give It a Year
# 8        9   doc_659032                                              Red 2
# 9       10   doc_632420               Professor Marston & The Wonder Women
#
#                                            Fragmento  Similitud
# 0  Although the relationship between Oliver and J...     0.5417
# 1  This romantic comedy is ambitious and thoughtf...     0.5195
# 2  Even when it's slowing down, Fight shows begui...     0.5024
# 3  According to The Story of Us, men and women ha...     0.5014
# 4  To call this an unlikely love story is an unde...     0.5009
# 5  Exploring a relationship by flicking between b...     0.4892
# 6  Father is a very intimate film, and writer-dir...     0.4887
# 7  Turns the romantic comedy on its head by utili...     0.4823
# 8  RED 2 is perilously close to a formulaic roman...     0.4818
# 9  What's so surprising is how [Angela] Robinson,...     0.4805
# Q3: action movie with intense fight scenes
#    Ranking           ID                            Título  \
# 0        1   doc_187855            Brawl in Cell Block 99
# 1        2   doc_933350       The Man With the Iron Fists
# 2        3   doc_818205  Star Wars: The Rise of Skywalker
# 3        4   doc_501883               Love at First Fight
# 4        5  doc_1012709                           Valiant
# 5        6   doc_658774                         Red Tails
# 6        7   doc_463376                         Klitschko
# 7        8    doc_19564    Invasion of the Body Snatchers
# 8        9   doc_501885               Love at First Fight
# 9       10   doc_894099                       The Fighter
#
#                                            Fragmento  Similitud
# 0  If you revel in brutality and find hard-to-wat...     0.5996
# 1  he film does have some interesting choreograph...     0.5800
# 2  Star Wars: The Rise of Skywalker is a film ful...     0.5774
# 3  Even when it's slowing down, Fight shows begui...     0.5691
# 4  A disarmingly enjoyable movie with a lively ca...     0.5683
# 5  Some exciting action as the pilots engage in d...     0.5469
# 6  Great action footage combined with learned int...     0.5441
# 7  A film whose righteous anger is visible in its...     0.5413
# 8  What matters in a movie like this is the relat...     0.5367
# 9  A phenomenal piece of work. Wahlberg, Bale, Ad...     0.5356
# Q4: horror film that creates fear and suspense
#    Ranking          ID                           Título  \
# 0        1   doc_21553         Night of the Living Dead
# 1        2  doc_765191                  The Sixth Sense
# 2        3  doc_971761                     The Wretched
# 3        4  doc_124159              Annabelle: Creation
# 4        5  doc_360481  Goosebumps 2: Haunted Halloween
# 5        6  doc_809022                     Stage Fright
# 6        7  doc_424667                        Insidious
# 7        8   doc_96356                    The Abandoned
# 8        9  doc_432464                               It
# 9       10  doc_715756                    Scary Movie 4
#
#                                            Fragmento  Similitud
# 0  A tightly-edited, claustrophobically-framed ho...     0.6813
# 1  A serious, thought-provoking film that contain...     0.6577
# 2  For the most part, this is a comfortably ordin...     0.6392
# 3  Too fixated on the explosive and bombastic pro...     0.6343
# 4  It's less like watching a sequel and more like...     0.6332
# 5  A film with this title and this plot descripti...     0.6312
# 6  The film never approaches being scary, but its...     0.6243
# 7  It is, to put it simply, a totally kick-ass ho...     0.6153
# 8  It is a horror movie that should delight fans ...     0.6105
# 9  There are some laughs in this latest installment.     0.6058
# Q5: visually impressive movie with weak storyline
#    Ranking           ID                                    Título  \
# 0        1   doc_699819                        Running From Crazy
# 1        2   doc_652179                                       Raw
# 2        3   doc_781176                   Solo: A Star Wars Story
# 3        4  doc_1012709                                   Valiant
# 4        5   doc_108404                       Aliens in the Attic
# 5        6   doc_957739                       The Spectacular Now
# 6        7   doc_852585  Tale of Tales (Il racconto dei racconti)
# 7        8  doc_1029363                          We Own the Night
# 8        9  doc_1002564                                  Unbroken
# 9       10   doc_414263                                 Immortals
#
#                                            Fragmento  Similitud
# 0  The narratively jumbled film ... features too ...     0.6240
# 1  "Raw" is a lot of things: a terrific feature d...     0.5930
# 2        This is franchise film-making at its worst.     0.5669
# 3  A disarmingly enjoyable movie with a lively ca...     0.5607
# 4  The whole enterprise is frustratingly 'blah' -...     0.5579
# 5  The Spectacular Now marks the return of the gr...     0.5521
# 6  The result is a visually stunning movie, meldi...     0.5500
# 7  It's a solid, if unremarkable piece of storyte...     0.5476
# 8  A lacklustre and dull film about an incredibly...     0.5458
# 9  It's got a weak story, weak characters, weak a...     0.5448
# Q6: emotionally moving performance by the lead actor
#    Ranking          ID             Título  \
# 0        1  doc_938079   The New Romantic
# 1        2  doc_941540      The Other Son
# 2        3  doc_424438        The Insider
# 3        4  doc_914685  The Ides of March
# 4        5  doc_890212    The End of Love
# 5        6  doc_501153      Love Actually
# 6        7  doc_735417          Sex Drive
# 7        8   doc_14137             Frozen
# 8        9  doc_851258      Take the Lead
# 9       10  doc_244640            Creep 2
#
#                                            Fragmento  Similitud
# 0  Clever writing and a solid lead actor will onl...     0.5401
# 1  A provocative, moving social drama, superbly t...     0.5176
# 2  It's the Oscar-caliber performances that comma...     0.5083
# 3  Without anyone noticing, George Clooney has be...     0.5075
# 4  Webber appears to be making an audition tape w...     0.4999
# 5  Whatever the actors are given to do they make ...     0.4991
# 6  Given the absence of any real freshness or ins...     0.4911
# 7  McKoen shows an evocative, emotional style wit...     0.4805
# 8  This handsomely lighted movie has the craft to...     0.4689
# 9  It should be harder to sell this character wit...     0.4682
# Q7: predictable plot but entertaining experience
#    Ranking           ID                            Título  \
# 0        1  doc_1012709                           Valiant
# 1        2   doc_257699                     Dead Man Down
# 2        3   doc_493228                     Live By Night
# 3        4   doc_559115                 Mutant Chronicles
# 4        5   doc_142986        Back to the Future Part II
# 5        6    doc_13123                             Chloe
# 6        7   doc_220688                      Child's Play
# 7        8   doc_761705  Sinbad: Legend of the Seven Seas
# 8        9   doc_722227                         Searching
# 9       10   doc_934169                   The Maze Runner
#
#                                            Fragmento  Similitud
# 0  A disarmingly enjoyable movie with a lively ca...     0.5513
# 1  A pleasingly intricate double (or is it triple...     0.5418
# 2  Man, that plot. You really can't pick where th...     0.5244
# 3  Mutant Chronicles has an intriguing premise, g...     0.5169
# 4                              Solidly entertaining.     0.5124
# 5  It has a starry cast, a twisty plot that clear...     0.5063
# 6  If the plotting and character beats are a tad ...     0.5060
# 7  The effects are competent, the action has exci...     0.5046
# 8  That a thriller would come along utilizing the...     0.5016
# 9  The Maze Runner is a slickly plot-driven flick...     0.4977
# Q8: movie praised by critics but unpopular with audiences
#    Ranking          ID                                         Título  \
# 0        1    doc_9039                                  The Promotion
# 1        2  doc_753451                                        Shut In
# 2        3  doc_377022  Harry Potter and the Deathly Hallows - Part 2
# 3        4  doc_432464                                             It
# 4        5  doc_690231                                     Rollerball
# 5        6  doc_887443                       The Disappointments Room
# 6        7  doc_781176                        Solo: A Star Wars Story
# 7        8  doc_418973                                      Incendies
# 8        9  doc_871566                            The Best of Enemies
# 9       10   doc_37139                            10 Cloverfield Lane
#
#                                            Fragmento  Similitud
# 0  I predict that when this film is released, lot...     0.5990
# 1  Shut In is a very bad movie anchored by a very...     0.5489
# 2  If ever there was a critic-proof film, this is...     0.5373
# 3  It is a horror movie that should delight fans ...     0.5232
# 4  A movie of such rank stupidity and appalling t...     0.5111
# 5  Disappointments has the strange confidence of ...     0.5081
# 6        This is franchise film-making at its worst.     0.4957
# 7  It is the very fact that the hatred is blind, ...     0.4908
# 8  This movie isn't just tone-deaf, it's ass back...     0.4848
# 9  With or without the Cloverfield business, 10 C...     0.4815

# %% [markdown]
# ## Parte 5: Tabla Resumen General

# %%
resumen_df = pd.DataFrame([
    {
        'Consulta': q_id,
        'Texto Consulta': query,
        'Documento Top-1': results_by_query[q_id].iloc[0]['ID'],
        'Título Película': results_by_query[q_id].iloc[0]['Título'],
        'Similitud': results_by_query[q_id].iloc[0]['Similitud']
    }

    for q_id, query in queries.items()
])

print("Tabla Resumen General")
display(resumen_df)
# Out:
# Tabla Resumen General
#   Consulta                                     Texto Consulta Documento Top-1  \
# 0       Q1     science fiction movie with advanced technology      doc_990707
# 1       Q2        romantic story with emotional relationships      doc_503575
# 2       Q3             action movie with intense fight scenes      doc_187855
# 3       Q4         horror film that creates fear and suspense       doc_21553
# 4       Q5      visually impressive movie with weak storyline      doc_699819
# 5       Q6   emotionally moving performance by the lead actor      doc_938079
# 6       Q7       predictable plot but entertaining experience     doc_1012709
# 7       Q8  movie praised by critics but unpopular with au...        doc_9039
#
#                   Título Película  Similitud
# 0  Transformers: Dark of the Moon     0.5192
# 1                      Love Story     0.5417
# 2          Brawl in Cell Block 99     0.5996
# 3        Night of the Living Dead     0.6813
# 4              Running From Crazy     0.6240
# 5                The New Romantic     0.5401
# 6                         Valiant     0.5513
# 7                   The Promotion     0.5990

# %% [markdown]
# ## Valor Agregado: Visualización de embeddings con PCA

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# Embeddings de queries
query_texts = list(queries.values())

query_embeddings = model.encode(
    query_texts,
    normalize_embeddings=True
)

# Combinar embeddings
all_embeddings = np.vstack([embeddings, query_embeddings])

# PCA
pca = PCA(n_components=2)

all_2d = pca.fit_transform(all_embeddings)

# Separar documentos y queries
doc_2d = all_2d[:len(embeddings)]
query_2d = all_2d[len(embeddings):]

# Plot
plt.figure(figsize=(24, 16))

# Documentos
plt.scatter(
    doc_2d[:, 0],
    doc_2d[:, 1],
    alpha=0.3,
    label='Documentos'
)

# Queries
plt.scatter(
    query_2d[:, 0],
    query_2d[:, 1],
    s=120,
    marker='x',
    label='Queries'
)

# Etiquetas queries
for i, q_id in enumerate(queries.keys()):

    plt.text(
        query_2d[i, 0],
        query_2d[i, 1],
        q_id,
        fontsize=10
    )

plt.title('Visualización PCA de Embeddings')
plt.xlabel('PC1')
plt.ylabel('PC2')

plt.legend()

plt.show()

# %% [markdown]
# # Language Models Con Gemini

# %%
querycli = "science fiction movie with advanced technology"
results = buscar_documentos(query, k=10)

prompt = f"""
Mi usuario quiere saber: {querycli}

Mi sistema de información encontró lo siguiente:
{results}

Responde únicamente basándote en los datos encontrados por el sistema SRI.
Si no encuentras la información en los datos proporcionados, indícalo claramente.
"""

# %%
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6******************************")

respuesta = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print(respuesta.text)
# Out:
# Basándome únicamente en los datos proporcionados por el sistema SRI, las películas que podrían ajustarse a la descripción de "ciencia ficción con tecnología avanzada" son:
#
# *   **Solo: A Star Wars Story (ID: doc_781176)**: El título "Star Wars" es indicativo de un género de ciencia ficción que típicamente presenta tecnología avanzada. Aunque el fragmento proporcionado no detalla la tecnología ("This is franchise film-making at its worst."), la franquicia es conocida por ello.
# *   **10 Cloverfield Lane (ID: doc_37139)**: La saga "Cloverfield" se asocia con el género de ciencia ficción, que a menudo incluye elementos de tecnología avanzada o inusual. El fragmento tampoco especifica la tecnología ("With or without the Cloverfield business, 10 C...").
#
# El resto de los fragmentos no proporcionan información que sugiera que las otras películas sean de ciencia ficción o que contengan tecnología avanzada.
